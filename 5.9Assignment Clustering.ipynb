# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,  classification_report
from sklearn import tree
from sklearn.cluster import SpectralClustering, AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
import scipy.cluster.hierarchy as sch

# %%
prob = pd.read_csv('airline-safety.csv')

# %%
prob
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
X=prob[['fatal_accidents_85_99']]
Y=prob[['incidents_85_99']]
X1=prob[['fatal_accidents_00_14']]
Y1=prob[['incidents_00_14']]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3, random_state=10)
x_train, x_test, y_train, y_test = train_test_split(X1,Y1, test_size=0.3, random_state=10)

# %%
clustering = AgglomerativeClustering().fit(X)
clustering
clustering1 = AgglomerativeClustering().fit(X1)
clustering
# Out:
# AgglomerativeClustering()

# %%
scaler = StandardScaler()
scaler.fit_transform(X_train)
kmeans = KMeans(n_clusters = 7)
y_means = kmeans.fit_predict(X_train)

centroids = kmeans.cluster_centers_

plt.figure(figsize = (10,10))
plt.title('Agglomerative clustering')
Dendrogram = sch.dendrogram((sch.linkage(X_train, method = 'ward')))

ac = AgglomerativeClustering(n_clusters = 7)
y_ac = ac.fit_predict(X)

# %%
y_clustering = clustering2.fit_predict(X_train)
y_clustering
# Out:
# array([0, 4, 4, 0, 0, 4, 2, 1, 2, 0, 3, 3, 7, 6, 2, 5, 0, 2, 4, 4, 0, 3,
#        0, 3, 2, 0, 4, 7, 4, 2, 2, 2, 2, 4, 5, 2, 2, 5, 0])

# %%
y_clustering1= clustering2.fit_predict(x_train)
y_clustering1
# Out:
# A:\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1255: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# array([1, 1, 1, 1, 2, 1, 1, 0, 1, 2, 2, 1, 2, 2, 0, 2, 1, 1, 0, 1, 2, 3,
#        0, 0, 1, 1, 1, 2, 1, 0, 1, 2, 0, 1, 0, 1, 1, 0, 1])

# %%
centroids = kmeans.cluster_centers_

# %%
plt.scatter(y_clustering,y_clustering1, c= "green", s=8 )

# %%
plt.scatter(X,Y, c= "green", s=8 )
plt.title('Clustering')
# Out:
# Text(0.5, 1.0, 'Clustering')

# %%
plt.plot(centroids )

# %%
plt.plot(y_clustering)
plt.plot(y_clustering1)

# %%
plt.plot(y_ac)

# %% [markdown]
# I have tried to get similar models with the information and I can see that the clustering that I have tried is not working as I had predicted. I will keep trying to get differing results. However my efforts are not showing similar data when I try the different clustering methods.
